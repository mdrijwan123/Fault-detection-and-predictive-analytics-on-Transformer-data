# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
os.chdir("C:\\Users\\Mohammed Rizwan\\Documents\\Data Science and Machine learning journey\\Jupyter notebook\\Misc Projects")

# %%
t_data=pd.read_csv("Trans_data.csv")

# %%
t_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8359 entries, 0 to 8358
# Data columns (total 43 columns):
# sample_number         8359 non-null int64
# result_number         8359 non-null int64
# text_id               8359 non-null object
# sampled_date          8359 non-null object
# recd_date             8359 non-null object
# date_completed        8359 non-null object
# date_reviewed         8359 non-null object
# sample_status         8359 non-null object
# sample_in_spec        8359 non-null object
# group_name            8359 non-null object
# t_site                8359 non-null object
# t_plant               8359 non-null object
# process_unit          8359 non-null object
# sampling_point        8359 non-null object
# product               8359 non-null object
# product_grade         8359 non-null object
# product_version       8359 non-null int64
# stage                 8359 non-null object
# sample_type           8359 non-null object
# ...

# %%
t_data.describe()
# Out:
#        sample_number  result_number  product_version  test_comment  \
# count   8.359000e+03   8.359000e+03           8359.0           0.0
# mean    1.080150e+07   5.637023e+07              1.0           NaN
# std     6.403573e+04   3.513793e+05              0.0           NaN
# min     1.073533e+07   5.598833e+07              1.0           NaN
# 25%     1.077754e+07   5.623648e+07              1.0           NaN
# 50%     1.078474e+07   5.627995e+07              1.0           NaN
# 75%     1.079157e+07   5.631995e+07              1.0           NaN
# max     1.098826e+07   5.739251e+07              1.0           NaN
#
#        numeric_entry  order_number    min_value    max_value  analysis_type  \
# count   7.417000e+03   8359.000000  1275.000000  4544.000000   8.359000e+03
# mean    4.678613e+05     20.413805    47.709490   285.953823   1.000662e+09
# std     2.190486e+06      8.320308    46.914489   637.625856   5.304543e+04
# ...

# %%
t_data.head()
# Out:
#    sample_number  result_number                                   text_id  \
# 0       10735333       55988327  OIL/NGP-DHC-SUB-55ETDC055001/011117@1159
# 1       10735333       55988328  OIL/NGP-DHC-SUB-55ETDC055001/011117@1159
# 2       10735333       55988329  OIL/NGP-DHC-SUB-55ETDC055001/011117@1159
# 3       10735333       55988330  OIL/NGP-DHC-SUB-55ETDC055001/011117@1159
# 4       10735333       55988331  OIL/NGP-DHC-SUB-55ETDC055001/011117@1159
#
#       sampled_date         recd_date    date_completed     date_reviewed  \
# 0  11/28/2016 0:00  11/15/2017 12:49  11/17/2017 18:44  11/17/2017 18:44
# 1  11/28/2016 0:00  11/15/2017 12:49  11/17/2017 18:44  11/17/2017 18:44
# 2  11/28/2016 0:00  11/15/2017 12:49  11/17/2017 18:44  11/17/2017 18:44
# 3  11/28/2016 0:00  11/15/2017 12:49  11/17/2017 18:44  11/17/2017 18:44
# 4  11/28/2016 0:00  11/15/2017 12:49  11/17/2017 18:44  11/17/2017 18:44
#
#   sample_status sample_in_spec       group_name    ...     order_number  \
# ...

# %%
df=t_data.groupby('sampling_point')

# %%
tid=t_data.sampling_point.unique()

# %%
tsample_data=t_data.sampled_date.unique()

# %%
raw_info=[]
for ID,tsample in zip(tid,tsample_data):
    raw_info.append((ID,tsample))

# %%
len(tsample_data)
# Out:
# 31
